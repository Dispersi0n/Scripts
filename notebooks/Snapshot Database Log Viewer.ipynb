# %% [markdown]
# # Snapshot Database Log Viewer

# %%
from sqlalchemy.engine import create_engine
import pandas as pd
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# FIXME: right now all the scripts hardcode kosmala's database login - this should be centralized somewhere more secure

# %%
dbcreds = dict(user='kosmala',passwd='uvNaui5sg',dbname='packerc_snapshot_serengeti')

# %% [markdown]
# ### Background
#
# In `/home/packerc/shared/metadata_db/scripts` there are a number of scripts for manipulating the metadata database. This folder includes a common function library `SnapshotDB.py`
#
# * Note - we probably want to use Jupyter to expose functionality from these scripts, not recreate them
#
# One of the functions provided allows logging each time one of these scripts is run. The log is a table in the metadata database. Here, as an illustration of connecting to the database and viewing a query, we provide a view of the log.

# %%
db = create_engine('mysql+pymysql://{user}:{passwd}@mysql/{dbname}'.format_map(dbcreds))

# %%
log = pd.read_sql_query(
    'SELECT idLog, Time, Name, Initials, Notes from Log JOIN People ON Log.Person = People.idPeople',
    db)
log
# Out:
#      idLog                Time              Name Initials  \
# 0        1 2014-06-06 18:08:11  Margaret Kosmala       MK
# 1        2 2014-06-06 18:10:56  Margaret Kosmala       MK
# 2        3 2014-06-06 18:11:14  Margaret Kosmala       MK
# 3        4 2014-06-06 18:11:28  Margaret Kosmala       MK
# 4        5 2014-06-06 18:11:37  Margaret Kosmala       MK
# 5        6 2014-06-06 18:15:27  Margaret Kosmala       MK
# 6        7 2014-06-06 18:17:45  Margaret Kosmala       MK
# 7        8 2014-06-06 18:21:09  Margaret Kosmala       MK
# 8        9 2014-06-06 18:21:15  Margaret Kosmala       MK
# 9       10 2014-06-06 18:38:35  Margaret Kosmala       MK
# 10      11 2014-06-06 18:55:54  Margaret Kosmala       MK
# 11      12 2014-06-06 19:10:22  Margaret Kosmala       MK
# 12      13 2014-06-06 19:28:22  Margaret Kosmala       MK
# 13      14 2014-06-06 20:00:48  Margaret Kosmala       MK
# 14      15 2014-06-06 20:21:40  Margaret Kosmala       MK
# ...

# %%
# Don't actually log this anywhere right now
#log.to_csv(...)
